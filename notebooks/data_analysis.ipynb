# %%
# Cell 1: Imports
import pandas as pd
import missingno as msno # Good for visualizing missing data

# %%
# Cell 2: Load the data
df = pd.read_csv('../data/heart.csv')
print(f"Dataset Shape: {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# Dataset Shape: 303 rows and 14 columns

# %%
# Cell 3: Identify Features and Target
print("\n--- Columns ---")
print(df.columns.tolist())
# Out:
# --- Columns ---
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
# Cell 4: Check for missing values
print("\n--- Missing Values ---")
print(df.isnull().sum())
# Out:
# --- Missing Values ---
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
# Cell 5: Check Target Distribution (Binary check)
print("\n--- Target Distribution (0 = No Disease, 1 = Disease) ---")
print(df['target'].value_counts())
# Out:
# --- Target Distribution (0 = No Disease, 1 = Disease) ---
# target
# 0    164
# 1    139
# Name: count, dtype: int64
